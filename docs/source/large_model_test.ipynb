# %% [markdown]
# # Test simulation of "huge" stratified model

# %% [markdown]
# ### Load dependencies and interfaces

# %%
import os
import pyciemss

# %% [markdown]
# ### Select model and parameters for sampling

# %%
model1 = "strat_eta_model.json"

start_time = 0.0
end_time = 5.0
logging_step_size = 1.0
num_samples = 1

# %% [markdown]
# ### Simulate

# %%
result1 = pyciemss.sample(model1, end_time, logging_step_size, num_samples, start_time=start_time)
display(result1['data'].head())
