# %%
import os
import pyciemss
import torch

from pyciemss.compiled_dynamics import CompiledDynamics

import pyciemss.visuals.plots as plots
import pyciemss.visuals.vega as vega
import pyciemss.visuals.trajectories as trajectories

# %%
MODEL_PATH = "https://raw.githubusercontent.com/gyorilab/mira/main/notebooks/hackathon_2024.02/scenario5/"

stockflow = os.path.join(MODEL_PATH, "scenario_5_stockflow.json")

# %%
start_time = 0.0
end_time = 100.0
logging_step_size = 10.0
num_samples = 1 # these models do not include uncertainty, so only one sample is needed

# %%
# Print Chen petrinet dynamics
stockflow_model = CompiledDynamics.load(stockflow)
display(stockflow_model)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/pyciemss/lib/python3.11/site-packages/sympytorch/sympy_module.py:170, in _Node.__init__(self, expr, _memodict, _func_lookup, **kwargs)
#     169 try:
# --> 170     arg_ = _memodict[arg]
#     171 except KeyError:
#
# KeyError: (Min(0.9, fr_fatality) - 1)*delay3i(icu_admissions, delay_recovery_sym_extreme, 0)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/pyciemss/lib/python3.11/site-packages/sympytorch/sympy_module.py:170, in _Node.__init__(self, expr, _memodict, _func_lookup, **kwargs)
#     169 try:
# --> 170     arg_ = _memodict[arg]
#     171 except KeyError:
#
# KeyError: delay3i(icu_admissions, delay_recovery_sym_extreme, 0)
#
# ...
